# %%
import pandas as pd

path_to_ny_sales = '../datasets/nyc-property/transformed_nyc_housing.csv'
sales_df = pd.read_csv(path_to_ny_sales)
sales_df.head(100)
# Out:
#     BOROUGH  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# 0         1                  5                 0            5
# 1         1                 10                 0           10
# 2         1                  6                 0            6
# 3         1                  8                 0            8
# 4         1                 24                 0           24
# ..      ...                ...               ...          ...
# 95        1                 48                 0           48
# 96        1                  4                 2            6
# 97        1                  2                 2            4
# 98        1                  2                 1            3
# 99        1                 22                 2           24
#
#     LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  SALE PRICE  \
# 0           0.000386           0.001717        1900   6625000.0
# 1           0.000537           0.001811        1913   3936272.0
# ...

# %%
sales_df.describe()

# Notice, the CSV format isn't actually smart enough to "remember" that borough is supposed to be categorical...
# Out:
#             BOROUGH  RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  \
# count  48244.000000       48244.000000      48244.000000  48244.000000
# mean       3.251741           2.566537          0.249171      2.834632
# std        0.903136          17.465481         10.988072     20.750418
# min        1.000000           0.000000          0.000000      0.000000
# 25%        3.000000           1.000000          0.000000      1.000000
# 50%        3.000000           1.000000          0.000000      1.000000
# 75%        4.000000           2.000000          0.000000      2.000000
# max        5.000000        1844.000000       2261.000000   2261.000000
#
#        LAND SQUARE FEET  GROSS SQUARE FEET    YEAR BUILT    SALE PRICE
# count      48244.000000       48244.000000  48244.000000  4.824400e+04
# mean           0.000794           0.000978   1827.765173  1.153281e+06
# std            0.007435           0.007859    464.361153  1.340131e+07
# ...
