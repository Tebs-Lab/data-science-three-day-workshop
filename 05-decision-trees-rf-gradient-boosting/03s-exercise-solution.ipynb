# %% [markdown]
# ## Part 1: Decision Trees With Grid Search
#
# Look at the sklearn [DecisionTreeClassifier documentation](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html). For each hyperparameter:
#
# * Decide if it will impact the results or exclusively impact the computational speed.
#     * **Only the `ccp_alpha` value exclusively impacts computational speed.**
#     * However, some values don't always make sense...
#     * For example, you'll only want to use `class_weight` unless you have imbalanced classes in your dataset [(learn more here)](https://machinelearningmastery.com/cost-sensitive-decision-trees-for-imbalanced-classification/)
# * Pick at least 3 values for each hyperparameter that you'd like to include in your grid search.
#     * If there are fewer than 3 valid choices, include all valid choices.
#     * Carefully consider the choices, try to predict the impact of this hyperparameter on the outcome.
#     * Does this hyperparameter interact with others?
#
# See my choices of values below.
#
#
# **criterion** {“gini”, “entropy”}, default=”gini”
#
# > Typically you'll end up with similar results using either of these. Gini is a bit faster to compute than entropy. Gini is a measure of "purity" while entropy is a measure of information/randomness. With Gini we are saying we want to maximize each split for homogeniety, with entropy we are maximizing the amount of "information gained" by performing the split in terms of reducing the randomness in the node. [Read more](https://towardsdatascience.com/gini-index-vs-information-entropy-7a7e4fed3fcb)
#
# **splitter** {“best”, “random”}, default=”best”
#
# > Best is most commonly used, and what almost everyone means when they describe a decision tree (including the lesson that this homework is based on...). Random will select still look at evrey feature but randomly select one split point per feature, then choose the best feature. I don't suggest it TBH — if you want to do something like this use a random forest instead. Using random will potentially avoid overfitting, but it will likely also decrease performance overall.
#
# **max_depth** int, default=None
#
# > The maximum depth of the tree. If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples. Shallow trees won't overfit as much, but at the risk of underfitting. Very shallow trees will only be allowed a few splits, whereas deeper trees will be allowed more. As the number of classess increases you may wish to increase the max_depth to allow your tree enough capacity to split out the classes. For example, if you have 10 classes, but a max depth of 3 (root->mid->leaf) then you'll have 4 leaf nodes, representing only 4 out of your possible 10 classes.
#
#
# **min_samples_split** int or float, default=2
#
# > The minimum number of samples required to split an internal node. Larger numbers here will smooth out the model by forcing your leaf nodes to represent a larger sub-sample of the data. This is especially true in regresssion trees, since you'll use the mean of that sub-sample as your prediction. However, as a consequence, with large numbers you might end up with "impure" leaf nodes that really ought to be split further.
#
#
# **min_weight_fraction_leaf** float, default=0.0
#
# > The minimum weighted fraction of the sum total of weights (of all the input samples) required to be at a leaf node. Samples have equal weight when sample_weight is not provided. This is similar to min_samples_split but more useful when you have imbalanced classes and are using class_weight.
#
#
# **max_features** int, float or {“auto”, “sqrt”, “log2”}, default=None
#
# > Artificially limit the number of features that can be considered at each split point. If you choose a value less than the number of features available that number of features will be randomly sampled per split. This is very common in random forests, and in a single decision tree it CAN have a regularizing effect but I don't generally recommend it.  This will also speed up the computational time by reduing the overall search space.
#
#
# **random_state** int, RandomState instance, default=None
#
# > This can impact the model when there are ties for best split, or when you're using random feature selection / max_features. For deterministic results, use it. If you don't need totally deterministic results, you can ignore it.
#
#
# **max_leaf_nodes** int, default=None
#
# > Grow a tree with max_leaf_nodes in best-first fashion. Best nodes are defined as relative reduction in impurity. If None then unlimited number of leaf nodes. An alternative way to perform regularization / stop the model from overfitting. Different from others above because it will cause the tree to grow "best split first" rather than just building the tree layer by layer.
#
#
# **min_impurity_decrease** float, default=0.0
#
# > A node will be split if this split induces a decrease of the impurity greater than or equal to this value. If splitting a node can't improve our metric (gini/entropy) by at least this much then a node won't be split. This will help us avoid overfitting, and it will smooth out our model somewhat, similar to min_samples_split.
#
#
# **class_weight** dict, list of dict or “balanced”, default=None
#
# > Weights associated with classes in the form {class_label: weight}. If None, all classes are supposed to have weight one. For multi-output problems, a list of dicts can be provided in the same order as the columns of y. See this link for more:
#
# **ccp_alpha** non-negative float, default=0.0
#
# > Complexity parameter used for Minimal Cost-Complexity Pruning. The subtree with the largest cost complexity that is smaller than ccp_alpha will be chosen. By default, no pruning is performed. See Minimal Cost-Complexity Pruning [(learn more here)](https://machinelearningmastery.com/cost-sensitive-decision-trees-for-imbalanced-classification/)

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV


# Load the data
heart_dataset = pd.read_csv('../datasets/uci-heart-disease/heart.csv')

# Split the data into input and labels
labels = heart_dataset['target']
input_data = heart_dataset.drop(columns=['target'])

# Note, we don't split the data. GridSearchCV will automatically apply 5-fold cross validation by default.


# Note, leaving out class_weights because our data is pretty balanced. 
tuned_parameters = {
    'criterion': ['gini', 'entropy'], # Very hard to say.
    'splitter': ['best', 'random'], # best will be best usually, but sometimes random can surprise you. 
    'max_depth': [None, 5, 10], # None is probably best, allow the tree to grow as much as it needs
    'min_samples_split': [2, 10, 30], # 2 gives the model the most power to overfit, but I think it will win.
    'max_features':[None, 'sqrt', 'log2'], # Hard to say, sqrt and log2 are very similar at this number of columns.
    'max_leaf_nodes': [None, 4, 20], # I suspect 4 will be quite bad, and None will win
    'min_impurity_decrease': [0, 0.01, .05, 0.1] # 0 or .01 will likely be best
}

# These two lines will result in every possible combo of the above paramters to be fit and scored
# which can take a LONG TIME with large datasets.
clf = DecisionTreeClassifier()
grid_tree = GridSearchCV(clf, tuned_parameters)
grid_tree.fit(input_data, labels) 

print("Best parameters set found on development set:")
print()
print(grid_tree.best_params_, grid_tree.best_score_)
print()
print("Grid scores on development set:")
print()
means = grid_tree.cv_results_['mean_test_score']
stds = grid_tree.cv_results_['std_test_score']



for mean, std, params in zip(means, stds, grid_tree.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
          % (mean, std * 2, params))
# Out:
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'} 0.8118032786885246
#
# Grid scores on development set:
#
# 0.752 (+/-0.103) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.765 (+/-0.124) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.775 (+/-0.097) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.762 (+/-0.091) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.789 (+/-0.060) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.746 (+/-0.041) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.792 (+/-0.114) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.756 (+/-0.066) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.785 (+/-0.118) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.766 (+/-0.106) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.802 (+/-0.090) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.776 (+/-0.101) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'best'}
# 0.716 (+/-0.097) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'best'}
# 0.729 (+/-0.050) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'best'}
# 0.752 (+/-0.048) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.703 (+/-0.159) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.640 (+/-0.158) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.643 (+/-0.174) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.798 (+/-0.125) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.743 (+/-0.094) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.798 (+/-0.125) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.762 (+/-0.107) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.798 (+/-0.125) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.759 (+/-0.122) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.798 (+/-0.125) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.805 (+/-0.084) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.798 (+/-0.125) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.746 (+/-0.060) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.798 (+/-0.125) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.769 (+/-0.122) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'best'}
# 0.729 (+/-0.054) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'best'}
# 0.746 (+/-0.115) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'best'}
# 0.749 (+/-0.079) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.687 (+/-0.160) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.687 (+/-0.160) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.650 (+/-0.174) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.779 (+/-0.078) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.798 (+/-0.066) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.769 (+/-0.102) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.782 (+/-0.104) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.795 (+/-0.056) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.756 (+/-0.120) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.782 (+/-0.107) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.756 (+/-0.047) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.792 (+/-0.120) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.762 (+/-0.056) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.808 (+/-0.089) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.736 (+/-0.086) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'best'}
# 0.739 (+/-0.056) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'best'}
# 0.706 (+/-0.072) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'best'}
# 0.749 (+/-0.058) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.689 (+/-0.164) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.710 (+/-0.180) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.627 (+/-0.134) for {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.716 (+/-0.068) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.749 (+/-0.037) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.762 (+/-0.113) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.778 (+/-0.133) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.789 (+/-0.128) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.736 (+/-0.072) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.742 (+/-0.136) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.657 (+/-0.197) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.752 (+/-0.113) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.736 (+/-0.073) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.759 (+/-0.114) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.746 (+/-0.047) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.759 (+/-0.055) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'best'}
# 0.690 (+/-0.162) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'random'}
# 0.756 (+/-0.048) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'best'}
# 0.723 (+/-0.125) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'random'}
# 0.696 (+/-0.125) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'best'}
# 0.686 (+/-0.112) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'random'}
# 0.674 (+/-0.219) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.574 (+/-0.115) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.578 (+/-0.139) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.554 (+/-0.037) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.611 (+/-0.166) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.746 (+/-0.062) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.710 (+/-0.243) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.759 (+/-0.044) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.696 (+/-0.148) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.759 (+/-0.111) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.690 (+/-0.167) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.755 (+/-0.119) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.690 (+/-0.178) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.722 (+/-0.192) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.756 (+/-0.033) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.733 (+/-0.207) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.743 (+/-0.044) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.647 (+/-0.171) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'best'}
# 0.628 (+/-0.215) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'random'}
# 0.706 (+/-0.086) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'best'}
# 0.624 (+/-0.203) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'random'}
# 0.736 (+/-0.047) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'best'}
# 0.647 (+/-0.181) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'random'}
# 0.749 (+/-0.052) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.574 (+/-0.115) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.640 (+/-0.165) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.611 (+/-0.172) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.613 (+/-0.166) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.574 (+/-0.115) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.769 (+/-0.107) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.746 (+/-0.057) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.739 (+/-0.074) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.786 (+/-0.093) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.706 (+/-0.080) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.729 (+/-0.052) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.769 (+/-0.093) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.723 (+/-0.131) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.762 (+/-0.039) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.739 (+/-0.118) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.765 (+/-0.080) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.726 (+/-0.086) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.743 (+/-0.094) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'best'}
# 0.660 (+/-0.195) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'random'}
# 0.693 (+/-0.151) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'best'}
# 0.670 (+/-0.162) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'random'}
# 0.687 (+/-0.173) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'best'}
# 0.664 (+/-0.205) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'random'}
# 0.693 (+/-0.159) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.628 (+/-0.215) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.667 (+/-0.133) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.601 (+/-0.151) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.607 (+/-0.147) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.611 (+/-0.172) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.690 (+/-0.081) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.716 (+/-0.175) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.716 (+/-0.146) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.746 (+/-0.087) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.742 (+/-0.077) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.756 (+/-0.067) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.789 (+/-0.114) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.680 (+/-0.144) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.776 (+/-0.065) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.732 (+/-0.181) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.749 (+/-0.097) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.707 (+/-0.138) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.742 (+/-0.097) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'best'}
# 0.577 (+/-0.128) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'random'}
# 0.743 (+/-0.071) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'best'}
# 0.646 (+/-0.160) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'random'}
# 0.743 (+/-0.070) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'best'}
# 0.670 (+/-0.244) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'random'}
# 0.578 (+/-0.139) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.604 (+/-0.139) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.640 (+/-0.236) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.578 (+/-0.139) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.574 (+/-0.115) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.746 (+/-0.165) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.690 (+/-0.153) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.762 (+/-0.149) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.733 (+/-0.098) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.789 (+/-0.095) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.703 (+/-0.162) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.782 (+/-0.055) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.702 (+/-0.170) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.772 (+/-0.113) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.697 (+/-0.157) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.713 (+/-0.096) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.660 (+/-0.151) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.726 (+/-0.093) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'best'}
# 0.634 (+/-0.221) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'random'}
# 0.726 (+/-0.080) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'best'}
# 0.581 (+/-0.141) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'random'}
# 0.716 (+/-0.075) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'best'}
# 0.666 (+/-0.153) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'random'}
# 0.634 (+/-0.197) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.670 (+/-0.207) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.650 (+/-0.174) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.577 (+/-0.128) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.782 (+/-0.093) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.730 (+/-0.092) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.753 (+/-0.062) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.739 (+/-0.049) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.745 (+/-0.138) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.776 (+/-0.119) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.749 (+/-0.099) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.752 (+/-0.081) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.742 (+/-0.069) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.746 (+/-0.085) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.762 (+/-0.071) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.743 (+/-0.080) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.729 (+/-0.096) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'best'}
# 0.644 (+/-0.190) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'random'}
# 0.729 (+/-0.075) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'best'}
# 0.746 (+/-0.066) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'random'}
# 0.706 (+/-0.034) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'best'}
# 0.654 (+/-0.185) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'random'}
# 0.621 (+/-0.189) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.574 (+/-0.115) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.644 (+/-0.171) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.700 (+/-0.168) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.545 (+/-0.009) for {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.779 (+/-0.108) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.782 (+/-0.059) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.765 (+/-0.092) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.792 (+/-0.036) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.795 (+/-0.056) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.799 (+/-0.054) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.785 (+/-0.118) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.762 (+/-0.100) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.785 (+/-0.118) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.782 (+/-0.099) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.802 (+/-0.090) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.812 (+/-0.046) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'best'}
# 0.753 (+/-0.078) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'best'}
# 0.746 (+/-0.073) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'best'}
# 0.759 (+/-0.059) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.703 (+/-0.175) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.706 (+/-0.169) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.660 (+/-0.123) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.798 (+/-0.125) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.782 (+/-0.118) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.798 (+/-0.125) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.762 (+/-0.082) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.798 (+/-0.125) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.766 (+/-0.088) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.798 (+/-0.125) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.785 (+/-0.091) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.798 (+/-0.125) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.772 (+/-0.102) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.798 (+/-0.125) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.769 (+/-0.069) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'best'}
# 0.739 (+/-0.077) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'best'}
# 0.759 (+/-0.051) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'best'}
# 0.736 (+/-0.071) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.667 (+/-0.199) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.736 (+/-0.076) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'best'}
# ...
# 0.802 (+/-0.139) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.699 (+/-0.186) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.766 (+/-0.059) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'best'}
# 0.673 (+/-0.210) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'random'}
# 0.746 (+/-0.034) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'best'}
# 0.703 (+/-0.171) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'random'}
# 0.739 (+/-0.062) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'best'}
# 0.700 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'random'}
# 0.739 (+/-0.071) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.677 (+/-0.156) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.742 (+/-0.063) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.581 (+/-0.152) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.713 (+/-0.176) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.630 (+/-0.212) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.723 (+/-0.117) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.723 (+/-0.103) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.696 (+/-0.044) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.703 (+/-0.133) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.762 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.762 (+/-0.053) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.785 (+/-0.057) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.749 (+/-0.083) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.789 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.726 (+/-0.137) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.789 (+/-0.061) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.736 (+/-0.111) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.766 (+/-0.060) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'best'}
# 0.690 (+/-0.189) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'random'}
# 0.680 (+/-0.143) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'best'}
# 0.706 (+/-0.174) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'random'}
# 0.736 (+/-0.062) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'best'}
# 0.732 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'random'}
# 0.706 (+/-0.084) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.607 (+/-0.162) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.706 (+/-0.139) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.634 (+/-0.158) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.657 (+/-0.195) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.643 (+/-0.156) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.716 (+/-0.035) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.726 (+/-0.129) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.743 (+/-0.107) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.719 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.752 (+/-0.030) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.717 (+/-0.183) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.752 (+/-0.131) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.736 (+/-0.064) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.736 (+/-0.052) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.736 (+/-0.042) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.776 (+/-0.062) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.729 (+/-0.175) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.730 (+/-0.096) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'best'}
# 0.624 (+/-0.196) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'random'}
# 0.746 (+/-0.133) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'best'}
# 0.607 (+/-0.160) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'random'}
# 0.759 (+/-0.040) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'best'}
# 0.703 (+/-0.161) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'random'}
# 0.722 (+/-0.081) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.601 (+/-0.151) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.746 (+/-0.112) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.600 (+/-0.131) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.736 (+/-0.061) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.660 (+/-0.188) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 4, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'random'}
# 0.799 (+/-0.118) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'best'}
# 0.749 (+/-0.080) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 2, 'splitter': 'random'}
# 0.736 (+/-0.169) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'best'}
# 0.739 (+/-0.095) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 10, 'splitter': 'random'}
# 0.733 (+/-0.078) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'best'}
# 0.769 (+/-0.111) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_split': 30, 'splitter': 'random'}
# 0.726 (+/-0.072) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'best'}
# 0.677 (+/-0.199) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 2, 'splitter': 'random'}
# 0.762 (+/-0.063) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'best'}
# 0.713 (+/-0.192) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 10, 'splitter': 'random'}
# 0.743 (+/-0.121) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'best'}
# 0.713 (+/-0.103) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.01, 'min_samples_split': 30, 'splitter': 'random'}
# 0.739 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'best'}
# 0.667 (+/-0.132) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 2, 'splitter': 'random'}
# 0.746 (+/-0.081) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'best'}
# 0.713 (+/-0.081) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 10, 'splitter': 'random'}
# 0.703 (+/-0.170) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'best'}
# 0.666 (+/-0.233) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.05, 'min_samples_split': 30, 'splitter': 'random'}
# 0.703 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.673 (+/-0.163) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.742 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.693 (+/-0.259) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.713 (+/-0.075) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'best'}
# 0.657 (+/-0.189) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.1, 'min_samples_split': 30, 'splitter': 'random'}

# %%
results = pd.DataFrame({'mean_accuracy': means, 'std': stds})
params_df = pd.DataFrame(grid_tree.cv_results_['params'], columns=grid_tree.cv_results_['params'][0].keys())
all_results = pd.concat([results, params_df], axis=1)
sorted_performances = all_results.sort_values('mean_accuracy', ascending=False)

sorted_performances.head(10)
# Out:
#       mean_accuracy       std criterion  max_depth max_features  \
# 227        0.811803  0.022866      gini        5.0         None
# 868        0.811749  0.046939   entropy        5.0         None
# 922        0.811749  0.046939   entropy        5.0         None
# 916        0.811749  0.046939   entropy        5.0         None
# 874        0.811749  0.046939   entropy        5.0         None
# 1090       0.808470  0.047977   entropy       10.0         None
# 700        0.808470  0.047977   entropy        NaN         None
# 1084       0.808470  0.047977   entropy       10.0         None
# 658        0.808470  0.047977   entropy        NaN         None
# 652        0.808470  0.047977   entropy        NaN         None
#
#       max_leaf_nodes  min_impurity_decrease  min_samples_split splitter
# 227              NaN                   0.01                 30   random
# 868              NaN                   0.00                 30     best
# 922             20.0                   0.01                 30     best
# 916             20.0                   0.00                 30     best
# 874              NaN                   0.01                 30     best
# 1090             NaN                   0.01                 30     best
# 700             20.0                   0.00                 30     best
# 1084             NaN                   0.00                 30     best
# 658              NaN                   0.01                 30     best
# 652              NaN                   0.00                 30     best

# %%
sorted_performances.tail(10)
# Out:
#      mean_accuracy       std criterion  max_depth max_features  \
# 789        0.54459  0.004417   entropy        NaN         sqrt
# 523        0.54459  0.004417      gini       10.0         sqrt
# 330        0.54459  0.004417      gini        5.0         sqrt
# 573        0.54459  0.004417      gini       10.0         sqrt
# 383        0.54459  0.004417      gini        5.0         log2
# 359        0.54459  0.004417      gini        5.0         sqrt
# 93         0.54459  0.004417      gini        NaN         sqrt
# 527        0.54459  0.004417      gini       10.0         sqrt
# 597        0.54459  0.004417      gini       10.0         log2
# 213        0.54459  0.004417      gini        NaN         log2
#
#      max_leaf_nodes  min_impurity_decrease  min_samples_split splitter
# 789            20.0                    0.1                 10   random
# 523             NaN                    0.1                  2   random
# 330             4.0                    0.1                  2     best
# 573            20.0                    0.1                 10   random
# 383             NaN                    0.1                 30   random
# 359            20.0                    0.1                 30   random
# 93              NaN                    0.1                 10   random
# 527             NaN                    0.1                 30   random
# 597             NaN                    0.1                 10   random
# 213            20.0                    0.1                 10   random

# %% [markdown]
# ## Any Patterns?
#
# What I see in the above is:
#
# high values in `min_samples_split` perform well the remaining top 10 are higher. Enforcing a `min_impurity_decrease` seems to hurt us generally, especially when using higher values. splitter value has "best" overrepresented in the top 10, but random does appear in the top 2!
#
# ## Bonus Challenges
#
# * Get the best performing model (look at the `best_estimator` property in the `GridSearchCV` documentation) and examine the `feature_importances_` of that `DecisionTree`. What are these, and what are they telling us?
#
# * Create another `GridSearchCV` but this time include more metrics to score the model.
#     * List of all built in metrics can be [found here](https://scikit-learn.org/stable/modules/classes.html#classification-metrics). I suggest using accuracy, precision, and recall.
#     * A demo of using multiple metrics can be [found here](https://scikit-learn.org/stable/auto_examples/model_selection/plot_multi_metric_evaluation.html#sphx-glr-auto-examples-model-selection-plot-multi-metric-evaluation-py)
#     * If you were building a real world medical screening system, how would you decide to value and balance these different metrics?
#         * [Read more about precision and recall](https://deepai.org/machine-learning-glossary-and-terms/precision-and-recall)
#         * Double bonus: can you make your GridSearch compute specificity as well? [Hint](https://stackoverflow.com/questions/47704133/how-to-define-specificity-as-a-callable-scorer-for-model-evaluation)

# %%
# Get the best estimator's feature importances.
# These tell us which features gave the model the most information as it split.
best_model = grid_tree.best_estimator_
feat_importances = pd.Series(best_model.feature_importances_, index=input_data.columns)
feat_importances.sort_values().plot(kind='barh', figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
# Multi Metric CV
from sklearn.metrics import accuracy_score, precision_score, recall_score, make_scorer

scoring = {
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score),
    'recall': make_scorer(recall_score),
    'specificity': make_scorer(recall_score,pos_label=0) # Note, this is the double bonus. Not too bad!
}

tuned_parameters = {
    'criterion': ['gini', 'entropy'], # Very hard to say.
    'splitter': ['best', 'random'], # best will be best usually, but sometimes random can surprise you. 
    'max_depth': [None, 5, 10], # None is probably best, allow the tree to grow as much as it needs
    'min_samples_split': [2, 10, 30], # 2 gives the model the most power to overfit, but I think it will win.
    'max_features':[None, 'sqrt', 'log2'], # Hard to say, sqrt and log2 are very similar at this number of columns.
    'max_leaf_nodes': [None, 4, 20], # I suspect 4 will be quite bad, and None will win
    'min_impurity_decrease': [0, 0.01, .05, 0.1] # 0 or .01 will likely be best
}


clf = DecisionTreeClassifier()

# refit=false basically means we aren't choosing one estimator as the "best" one
# We do this because we have multi-metric scoring and it's no longer clear which is "best"
grid_tree = GridSearchCV(clf, tuned_parameters, scoring=scoring, refit=False) 
grid_tree.fit(input_data, labels) 

grid_tree.cv_results_
# Out:
# {'mean_fit_time': array([0.00260091, 0.00205617, 0.00223756, ..., 0.00215011, 0.00214381,
#         0.00211282]),
#  'std_fit_time': array([0.00029989, 0.00024686, 0.00015577, ..., 0.00038808, 0.00038939,
#         0.00043101]),
#  'mean_score_time': array([0.00377436, 0.00374961, 0.00383835, ..., 0.00367808, 0.00370936,
#         0.00415335]),
#  'std_score_time': array([0.00045096, 0.00055029, 0.00069439, ..., 0.00022272, 0.00040231,
#         0.00071585]),
#  'param_criterion': masked_array(data=['gini', 'gini', 'gini', ..., 'entropy', 'entropy',
#                     'entropy'],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[None, None, None, ..., 10, 10, 10],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[None, None, None, ..., 'log2', 'log2', 'log2'],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_leaf_nodes': masked_array(data=[None, None, None, ..., 20, 20, 20],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_impurity_decrease': masked_array(data=[0, 0, 0, ..., 0.1, 0.1, 0.1],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_split': masked_array(data=[2, 2, 10, ..., 10, 30, 30],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_splitter': masked_array(data=['best', 'random', 'best', ..., 'random', 'best',
#                     'random'],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
# ...
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': None,
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 4,
#    'min_impurity_decrease': 0.1,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.01,
#    'min_samples_split': 30,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 5,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': 20,
#    'min_impurity_decrease': 0.05,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   ...],
#  'split0_test_accuracy': array([0.75409836, 0.80327869, 0.73770492, ..., 0.54098361, 0.78688525,
#         0.54098361]),
#  'split1_test_accuracy': array([0.83606557, 0.72131148, 0.85245902, ..., 0.54098361, 0.75409836,
#         0.73770492]),
#  'split2_test_accuracy': array([0.78688525, 0.75409836, 0.7704918 , ..., 0.54098361, 0.73770492,
#         0.54098361]),
#  'split3_test_accuracy': array([0.71666667, 0.7       , 0.73333333, ..., 0.55      , 0.78333333,
#         0.55      ]),
#  'split4_test_accuracy': array([0.73333333, 0.76666667, 0.71666667, ..., 0.55      , 0.73333333,
#         0.55      ]),
#  'mean_test_accuracy': array([0.76540984, 0.74907104, 0.76213115, ..., 0.54459016, 0.75907104,
#         0.58393443]),
#  'std_test_accuracy': array([0.04239381, 0.03592189, 0.048419  , ..., 0.00441711, 0.02238731,
#         0.07699091]),
#  'rank_test_accuracy': array([ 282,  449,  313, ..., 1285,  329, 1256], dtype=int32),
#  'split0_test_precision': array([0.84615385, 0.83870968, 0.81481481, ..., 0.54098361, 0.77777778,
#         0.54098361]),
#  'split1_test_precision': array([0.84848485, 0.80769231, 0.9       , ..., 0.54098361, 0.76470588,
#         0.69767442]),
#  'split2_test_precision': array([0.8125    , 0.78125   , 0.78787879, ..., 0.54098361, 0.68085106,
#         0.54098361]),
#  'split3_test_precision': array([0.75      , 0.72727273, 0.75757576, ..., 0.55      , 0.83333333,
#         0.55      ]),
#  'split4_test_precision': array([0.69767442, 0.77142857, 0.68181818, ..., 0.55      , 0.75757576,
#         0.55      ]),
#  'mean_test_precision': array([0.79096262, 0.78527066, 0.78841751, ..., 0.54459016, 0.76284876,
#         0.57592833]),
#  'std_test_precision': array([0.05865042, 0.03722899, 0.0713616 , ..., 0.00441711, 0.04887909,
#         0.06100645]),
#  'rank_test_precision': array([ 201,  272,  242, ..., 1285,  469, 1266], dtype=int32),
#  'split0_test_recall': array([0.66666667, 0.78787879, 0.66666667, ..., 1.        , 0.84848485,
#         1.        ]),
#  'split1_test_recall': array([0.84848485, 0.63636364, 0.81818182, ..., 1.        , 0.78787879,
#         0.90909091]),
#  'split2_test_recall': array([0.78787879, 0.75757576, 0.78787879, ..., 1.        , 0.96969697,
#         1.        ]),
#  'split3_test_recall': array([0.72727273, 0.72727273, 0.75757576, ..., 1.        , 0.75757576,
#         1.        ]),
#  'split4_test_recall': array([0.90909091, 0.81818182, 0.90909091, ..., 1.        , 0.75757576,
#         1.        ]),
#  'mean_test_recall': array([0.78787879, 0.74545455, 0.78787879, ..., 1.        , 0.82424242,
#         0.98181818]),
#  'std_test_recall': array([0.08570991, 0.06239776, 0.07902064, ..., 0.        , 0.07994488,
#         0.03636364]),
#  'rank_test_recall': array([ 845, 1144,  845, ...,    1,  575,   16], dtype=int32),
#  'split0_test_specificity': array([0.85714286, 0.82142857, 0.82142857, ..., 0.        , 0.71428571,
#         0.        ]),
#  'split1_test_specificity': array([0.82142857, 0.82142857, 0.89285714, ..., 0.        , 0.71428571,
#         0.53571429]),
#  'split2_test_specificity': array([0.78571429, 0.75      , 0.75      , ..., 0.        , 0.46428571,
#         0.        ]),
#  'split3_test_specificity': array([0.7037037 , 0.66666667, 0.7037037 , ..., 0.        , 0.81481481,
#         0.        ]),
#  'split4_test_specificity': array([0.51851852, 0.7037037 , 0.48148148, ..., 0.        , 0.7037037 ,
#         0.        ]),
#  'mean_test_specificity': array([0.73730159, 0.7526455 , 0.72989418, ..., 0.        , 0.68227513,
#         0.10714286]),
#  'std_test_specificity': array([0.12064652, 0.06205945, 0.13981025, ..., 0.        , 0.11627097,
#         0.21428571]),
#  'rank_test_specificity': array([ 236,  138,  281, ..., 1285,  539, 1274], dtype=int32)}

# %%
# Plus, check out this trick making the DF a bit easier to work with
results = pd.DataFrame({
    'accuracy': grid_tree.cv_results_['mean_test_accuracy'],
    'precision': grid_tree.cv_results_['mean_test_precision'],
    'recall': grid_tree.cv_results_['mean_test_recall'],
    'specificity': grid_tree.cv_results_['mean_test_specificity'],
})

params_df = pd.DataFrame(grid_tree.cv_results_['params'], columns=grid_tree.cv_results_['params'][0].keys())
all_results = pd.concat([results, params_df], axis=1)

# Lots of interesting analysis could be done on this dataframe now to learn
# about the trained models...
all_results
# Out:
#       accuracy  precision    recall  specificity criterion  max_depth  \
# 0     0.765410   0.790963  0.787879     0.737302      gini        NaN
# 1     0.749071   0.785271  0.745455     0.752646      gini        NaN
# 2     0.762131   0.788418  0.787879     0.729894      gini        NaN
# 3     0.788689   0.823714  0.787879     0.789418      gini        NaN
# 4     0.795246   0.801993  0.842424     0.737566      gini        NaN
# ...        ...        ...       ...          ...       ...        ...
# 1291  0.581257   0.572368  0.987879     0.096296   entropy       10.0
# 1292  0.729290   0.748648  0.757576     0.696032   entropy       10.0
# 1293  0.544590   0.544590  1.000000     0.000000   entropy       10.0
# 1294  0.759071   0.762849  0.824242     0.682275   entropy       10.0
# 1295  0.583934   0.575928  0.981818     0.107143   entropy       10.0
#
#      max_features  max_leaf_nodes  min_impurity_decrease  min_samples_split  \
# 0            None             NaN                    0.0                  2
# 1            None             NaN                    0.0                  2
# 2            None             NaN                    0.0                 10
# 3            None             NaN                    0.0                 10
# 4            None             NaN                    0.0                 30
# ...           ...             ...                    ...                ...
# 1291         log2            20.0                    0.1                  2
# 1292         log2            20.0                    0.1                 10
# 1293         log2            20.0                    0.1                 10
# 1294         log2            20.0                    0.1                 30
# 1295         log2            20.0                    0.1                 30
#
#      splitter
# 0        best
# 1      random
# 2        best
# 3      random
# 4        best
# ...       ...
# 1291   random
# 1292     best
# 1293   random
# 1294     best
# 1295   random
#
# [1296 rows x 11 columns]

# %%
all_results.sort_values('accuracy', ascending=False)
# Out:
#       accuracy  precision    recall  specificity criterion  max_depth  \
# 1275  0.815191   0.801310  0.878788     0.739153   entropy       10.0
# 802   0.811967   0.825153  0.842424     0.774603   entropy        NaN
# 874   0.811749   0.827331  0.830303     0.789153   entropy        5.0
# 922   0.811749   0.827331  0.830303     0.789153   entropy        5.0
# 916   0.811749   0.827331  0.830303     0.789153   entropy        5.0
# ...        ...        ...       ...          ...       ...        ...
# 91    0.544590   0.544590  1.000000     0.000000      gini        NaN
# 379   0.544590   0.544590  1.000000     0.000000      gini        5.0
# 213   0.544590   0.544590  1.000000     0.000000      gini        NaN
# 407   0.544590   0.544590  1.000000     0.000000      gini        5.0
# 619   0.544590   0.544590  1.000000     0.000000      gini       10.0
#
#      max_features  max_leaf_nodes  min_impurity_decrease  min_samples_split  \
# 1275         log2            20.0                   0.00                 10
# 802          log2             NaN                   0.01                 30
# 874          None             NaN                   0.01                 30
# 922          None            20.0                   0.01                 30
# 916          None            20.0                   0.00                 30
# ...           ...             ...                    ...                ...
# 91           sqrt             NaN                   0.10                  2
# 379          log2             NaN                   0.10                  2
# 213          log2            20.0                   0.10                 10
# 407          log2             4.0                   0.10                 30
# 619          log2             4.0                   0.10                  2
#
#      splitter
# 1275   random
# 802      best
# 874      best
# 922      best
# 916      best
# ...       ...
# 91     random
# 379    random
# 213    random
# 407    random
# 619    random
#
# [1296 rows x 11 columns]

# %%
all_results.sort_values('specificity', ascending=False)
# Out:
#       accuracy  precision    recall  specificity criterion  max_depth  \
# 661   0.759016   0.853653  0.672727     0.862169   entropy        NaN
# 553   0.772077   0.849650  0.709091     0.846825      gini       10.0
# 1016  0.768689   0.835455  0.715152     0.832540   entropy        5.0
# 827   0.699508   0.827528  0.600000     0.817725   entropy        NaN
# 965   0.699454   0.806478  0.606061     0.812434   entropy        5.0
# ...        ...        ...       ...          ...       ...        ...
# 191   0.544590   0.544590  1.000000     0.000000      gini        NaN
# 359   0.544590   0.544590  1.000000     0.000000      gini        5.0
# 311   0.544590   0.544590  1.000000     0.000000      gini        5.0
# 619   0.544590   0.544590  1.000000     0.000000      gini       10.0
# 1285  0.544590   0.544590  1.000000     0.000000   entropy       10.0
#
#      max_features  max_leaf_nodes  min_impurity_decrease  min_samples_split  \
# 661          None             NaN                   0.05                  2
# 553          sqrt            20.0                   0.00                  2
# 1016         log2             NaN                   0.01                 10
# 827          log2             4.0                   0.01                 30
# 965          sqrt             4.0                   0.00                 30
# ...           ...             ...                    ...                ...
# 191          log2             4.0                   0.10                 30
# 359          sqrt            20.0                   0.10                 30
# 311          sqrt             NaN                   0.10                 30
# 619          log2             4.0                   0.10                  2
# 1285         log2            20.0                   0.05                  2
#
#      splitter
# 661    random
# 553    random
# 1016     best
# 827    random
# 965    random
# ...       ...
# 191    random
# 359    random
# 311    random
# 619    random
# 1285   random
#
# [1296 rows x 11 columns]

# %%
all_results.sort_values('recall', ascending=False)
# Out:
#       accuracy  precision    recall  specificity criterion  max_depth  \
# 213   0.544590   0.544590  1.000000     0.000000      gini        NaN
# 311   0.544590   0.544590  1.000000     0.000000      gini        5.0
# 1293  0.544590   0.544590  1.000000     0.000000   entropy       10.0
# 95    0.544590   0.544590  1.000000     0.000000      gini        NaN
# 379   0.544590   0.544590  1.000000     0.000000      gini        5.0
# ...        ...        ...       ...          ...       ...        ...
# 169   0.660546   0.710589  0.630303     0.694974      gini        NaN
# 1181  0.646940   0.711773  0.618182     0.681217   entropy       10.0
# 585   0.643880   0.753917  0.612121     0.684127      gini       10.0
# 965   0.699454   0.806478  0.606061     0.812434   entropy        5.0
# 827   0.699508   0.827528  0.600000     0.817725   entropy        NaN
#
#      max_features  max_leaf_nodes  min_impurity_decrease  min_samples_split  \
# 213          log2            20.0                   0.10                 10
# 311          sqrt             NaN                   0.10                 30
# 1293         log2            20.0                   0.10                 10
# 95           sqrt             NaN                   0.10                 30
# 379          log2             NaN                   0.10                  2
# ...           ...             ...                    ...                ...
# 169          log2             4.0                   0.00                  2
# 1181         sqrt             4.0                   0.00                 30
# 585          log2             NaN                   0.01                 10
# 965          sqrt             4.0                   0.00                 30
# 827          log2             4.0                   0.01                 30
#
#      splitter
# 213    random
# 311    random
# 1293   random
# 95     random
# 379    random
# ...       ...
# 169    random
# 1181   random
# 585    random
# 965    random
# 827    random
#
# [1296 rows x 11 columns]

# %%
all_results.sort_values('precision', ascending=False)
# Out:
#       accuracy  precision    recall  specificity criterion  max_depth  \
# 661   0.759016   0.853653  0.672727     0.862169   entropy        NaN
# 553   0.772077   0.849650  0.709091     0.846825      gini       10.0
# 1154  0.791967   0.839605  0.781818     0.803704   entropy       10.0
# 437   0.798525   0.837155  0.787879     0.811376      gini       10.0
# 1016  0.768689   0.835455  0.715152     0.832540   entropy        5.0
# ...        ...        ...       ...          ...       ...        ...
# 619   0.544590   0.544590  1.000000     0.000000      gini       10.0
# 359   0.544590   0.544590  1.000000     0.000000      gini        5.0
# 1293  0.544590   0.544590  1.000000     0.000000   entropy       10.0
# 379   0.544590   0.544590  1.000000     0.000000      gini        5.0
# 213   0.544590   0.544590  1.000000     0.000000      gini        NaN
#
#      max_features  max_leaf_nodes  min_impurity_decrease  min_samples_split  \
# 661          None             NaN                   0.05                  2
# 553          sqrt            20.0                   0.00                  2
# 1154         sqrt             NaN                   0.00                 10
# 437          None             NaN                   0.00                 30
# 1016         log2             NaN                   0.01                 10
# ...           ...             ...                    ...                ...
# 619          log2             4.0                   0.10                  2
# 359          sqrt            20.0                   0.10                 30
# 1293         log2            20.0                   0.10                 10
# 379          log2             NaN                   0.10                  2
# 213          log2            20.0                   0.10                 10
#
#      splitter
# 661    random
# 553    random
# 1154     best
# 437    random
# 1016     best
# ...       ...
# 619    random
# 359    random
# 1293   random
# 379    random
# 213    random
#
# [1296 rows x 11 columns]

# %% [markdown]
# # Part 2, Random Forests
#
# The only new hyperparamters are:
#
# **n_estimators**
#
# > the number of trees to build. More is "better" but you'll hit a point of diminishing returns as bagging and feature selection can only create so much variance.
#
# **bootstrap**
#
# > Whether or not to use bagging. Generally you want this, otherwise your only source of variance is feature selection.
#
# **oob_score**
#
# > When bagging, you can use "out of bag" samples as a form of validation data, rather than splitting out a validation set explicitly. If your number of estimators is fairly high, you may not have many out of bag samples. We're using a validation set anyway, so we won't use this.
#
# **n_jobs**
#
# > Speed impacting only, we can build these trees in parallel and this value controls how many processes to spin up in that parallel creation process.
#
# **warm_start**
#
# > Only relevant for retraining an existing random forest — warm start can be used to add new estimators when calling .fit more than once on the same model. We won't use this either.
#
# Also note splitter is no longer available, best is always used for RFs.

# %%
from sklearn.ensemble import RandomForestClassifier

# Load the data
heart_dataset = pd.read_csv('../datasets/uci-heart-disease/heart.csv')

# Split the data into input and labels
labels = heart_dataset['target']
input_data = heart_dataset.drop(columns=['target'])

# Note, we don't split the data. GridSearchCV will automatically apply 5-fold cross validation by default.


# Note, leaving out class_weights because our data is pretty balanced. 
tuned_parameters = {
    'n_estimators': [10, 50, 100, 200], # 10 is too few, I guess 200 not tons better than 100
    'bootstrap': [True, False], # I guess false will generally perform worse
    'n_jobs': [-1],  # always using max number of jobs
    'criterion': ['gini', 'entropy'], # Not sure what will win out here TBH. Maybe gini.
    'max_depth': [None, 5, 10], # None is probably best, allow the tree to grow as much as it needs
    'min_samples_split': [2, 10, 30], # 2 gives the model the most power to overfit, but I think it will win.
    'max_features':['sqrt', 'log2'], # Quite similar overall.
    'max_leaf_nodes': [None, 4, 20], # I suspect 4 will be quite bad, and None will win
}

# Doing the scoring bonus.
scoring = {
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score),
    'recall': make_scorer(recall_score),
    'specificity': make_scorer(recall_score,pos_label=0) # Note, this is the double bonus. Not too bad!
}

# These two lines will result in every possible combo of the above paramters to be fit and scored
# which can take a LONG TIME with large datasets.
clf = RandomForestClassifier()
grid_tree = GridSearchCV(clf, tuned_parameters, scoring=scoring, n_jobs=-1, refit=False)
grid_tree.fit(input_data, labels)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 5, 10],
#                          'max_features': ['sqrt', 'log2'],
#                          'max_leaf_nodes': [None, 4, 20],
#                          'min_samples_split': [2, 10, 30],
#                          'n_estimators': [10, 50, 100, 200], 'n_jobs': [-1]},
#              refit=False,
#              scoring={'accuracy': make_scorer(accuracy_score),
#                       'precision': make_scorer(precision_score),
#                       'recall': make_scorer(recall_score),
#                       'specificity': make_scorer(recall_score, pos_label=0)})

# %%
# Plus, check out this trick making the DF a bit easier to work with
results = pd.DataFrame({
    'accuracy': grid_tree.cv_results_['mean_test_accuracy'],
    'precision': grid_tree.cv_results_['mean_test_precision'],
    'recall': grid_tree.cv_results_['mean_test_recall'],
    'specificity': grid_tree.cv_results_['mean_test_specificity'],
})

params_df = pd.DataFrame(grid_tree.cv_results_['params'], columns=grid_tree.cv_results_['params'][0].keys())
all_results = pd.concat([results, params_df], axis=1)

# Lots of interesting analysis could be done on this dataframe now to learn
# about the trained models...
all_results
# Out:
#      accuracy  precision    recall  specificity  bootstrap criterion  \
# 0    0.808306   0.829236  0.830303     0.780688       True      gini
# 1    0.798634   0.819811  0.812121     0.782011       True      gini
# 2    0.828197   0.834295  0.860606     0.788889       True      gini
# 3    0.814863   0.822782  0.848485     0.774339       True      gini
# 4    0.801694   0.812794  0.830303     0.768254       True      gini
# ..        ...        ...       ...          ...        ...       ...
# 859  0.821585   0.825481  0.860606     0.774339      False   entropy
# 860  0.821639   0.819351  0.866667     0.767460      False   entropy
# 861  0.834645   0.823872  0.890909     0.766931      False   entropy
# 862  0.828306   0.825904  0.872727     0.774868      False   entropy
# 863  0.811694   0.813866  0.854545     0.760053      False   entropy
#
#      max_depth max_features  max_leaf_nodes  min_samples_split  n_estimators  \
# 0          NaN         sqrt             NaN                  2            10
# 1          NaN         sqrt             NaN                  2            50
# 2          NaN         sqrt             NaN                  2           100
# 3          NaN         sqrt             NaN                  2           200
# 4          NaN         sqrt             NaN                 10            10
# ..         ...          ...             ...                ...           ...
# 859       10.0         log2            20.0                 10           200
# 860       10.0         log2            20.0                 30            10
# 861       10.0         log2            20.0                 30            50
# 862       10.0         log2            20.0                 30           100
# 863       10.0         log2            20.0                 30           200
#
#      n_jobs
# 0        -1
# 1        -1
# 2        -1
# 3        -1
# 4        -1
# ..      ...
# 859      -1
# 860      -1
# 861      -1
# 862      -1
# 863      -1
#
# [864 rows x 12 columns]

# %%
all_results.sort_values('accuracy', ascending=False)
# Out:
#      accuracy  precision    recall  specificity  bootstrap criterion  \
# 201  0.854699   0.836523  0.915152     0.782011       True      gini
# 166  0.854699   0.834184  0.921212     0.774868       True      gini
# 87   0.851366   0.829176  0.921212     0.767460       True      gini
# 10   0.851366   0.834946  0.909091     0.782011       True      gini
# 155  0.851366   0.835626  0.909091     0.781746       True      gini
# ..        ...        ...       ...          ...        ...       ...
# 616  0.785027   0.786908  0.842424     0.715344      False      gini
# 408  0.782077   0.768736  0.860606     0.687831       True   entropy
# 708  0.781967   0.783070  0.836364     0.716402      False   entropy
# 580  0.781803   0.782706  0.842424     0.708466      False      gini
# 432  0.768743   0.795423  0.781818     0.752910      False      gini
#
#      max_depth max_features  max_leaf_nodes  min_samples_split  n_estimators  \
# 201       10.0         log2             4.0                 30            50
# 166       10.0         sqrt             4.0                 30           100
# 87         5.0         sqrt             4.0                  2           200
# 10         NaN         sqrt             NaN                 30           100
# 155       10.0         sqrt             NaN                 30           200
# ..         ...          ...             ...                ...           ...
# 616       10.0         log2             NaN                 10            10
# 408       10.0         log2             4.0                  2            10
# 708        NaN         log2            20.0                  2            10
# 580       10.0         sqrt             NaN                 10            10
# 432        NaN         sqrt             NaN                  2            10
#
#      n_jobs
# 201      -1
# 166      -1
# 87       -1
# 10       -1
# 155      -1
# ..      ...
# 616      -1
# 408      -1
# 708      -1
# 580      -1
# 432      -1
#
# [864 rows x 12 columns]

# %%
all_results.sort_values('recall', ascending=False)
# Out:
#      accuracy  precision    recall  specificity  bootstrap criterion  \
# 125  0.847978   0.812011  0.939394     0.738624       True      gini
# 702  0.841475   0.807436  0.933333     0.731217      False   entropy
# 230  0.848087   0.817314  0.933333     0.746032       True   entropy
# 122  0.848087   0.820085  0.927273     0.753175       True      gini
# 740  0.828251   0.793722  0.927273     0.709788      False   entropy
# ..        ...        ...       ...          ...        ...       ...
# 216  0.791803   0.826443  0.787879     0.796296       True   entropy
# 220  0.788743   0.820496  0.787879     0.789947       True   entropy
# 36   0.785410   0.819131  0.787879     0.782011       True      gini
# 432  0.768743   0.795423  0.781818     0.752910      False      gini
# 144  0.788743   0.825457  0.775758     0.804233       True      gini
#
#      max_depth max_features  max_leaf_nodes  min_samples_split  n_estimators  \
# 125        5.0         log2             4.0                 10            50
# 702        NaN         log2             4.0                 10           100
# 230        NaN         sqrt             4.0                  2           100
# 122        5.0         log2             4.0                  2           100
# 740        5.0         sqrt             4.0                 30            10
# ..         ...          ...             ...                ...           ...
# 216        NaN         sqrt             NaN                  2            10
# 220        NaN         sqrt             NaN                 10            10
# 36         NaN         log2             NaN                  2            10
# 432        NaN         sqrt             NaN                  2            10
# 144       10.0         sqrt             NaN                  2            10
#
#      n_jobs
# 125      -1
# 702      -1
# 230      -1
# 122      -1
# 740      -1
# ..      ...
# 216      -1
# 220      -1
# 36       -1
# 432      -1
# 144      -1
#
# [864 rows x 12 columns]

# %%
all_results.sort_values('specificity', ascending=False)
# Out:
#      accuracy  precision    recall  specificity  bootstrap criterion  \
# 364  0.834863   0.871106  0.824242     0.846825       True   entropy
# 692  0.834809   0.852232  0.848485     0.817989      False   entropy
# 612  0.815082   0.845425  0.818182     0.810847      False      gini
# 684  0.804973   0.837235  0.800000     0.810847      False   entropy
# 396  0.811803   0.845673  0.812121     0.810582       True   entropy
# ..        ...        ...       ...          ...        ...       ...
# 196  0.791967   0.771145  0.878788     0.688095       True      gini
# 408  0.782077   0.768736  0.860606     0.687831       True   entropy
# 416  0.795027   0.772889  0.884848     0.687566       True   entropy
# 140  0.792022   0.769217  0.884848     0.680952       True      gini
# 300  0.788525   0.769998  0.878788     0.680159       True   entropy
#
#      max_depth max_features  max_leaf_nodes  min_samples_split  n_estimators  \
# 364       10.0         sqrt             NaN                 10            10
# 692        NaN         log2             NaN                 30            10
# 612       10.0         log2             NaN                  2            10
# 684        NaN         log2             NaN                  2            10
# 396       10.0         log2             NaN                  2            10
# ..         ...          ...             ...                ...           ...
# 196       10.0         log2             4.0                 10            10
# 408       10.0         log2             4.0                  2            10
# 416       10.0         log2             4.0                 30            10
# 140        5.0         log2            20.0                 30            10
# 300        5.0         sqrt             4.0                  2            10
#
#      n_jobs
# 364      -1
# 692      -1
# 612      -1
# 684      -1
# 396      -1
# ..      ...
# 196      -1
# 408      -1
# 416      -1
# 140      -1
# 300      -1
#
# [864 rows x 12 columns]

# %%
all_results.sort_values('precision', ascending=False)
# Out:
#      accuracy  precision    recall  specificity  bootstrap criterion  \
# 364  0.834863   0.871106  0.824242     0.846825       True   entropy
# 692  0.834809   0.852232  0.848485     0.817989      False   entropy
# 713  0.847978   0.849352  0.884848     0.803439      False   entropy
# 209  0.844645   0.847157  0.878788     0.803175       True      gini
# 857  0.838142   0.846974  0.866667     0.803439      False   entropy
# ..        ...        ...       ...          ...        ...       ...
# 416  0.795027   0.772889  0.884848     0.687566       True   entropy
# 196  0.791967   0.771145  0.878788     0.688095       True      gini
# 300  0.788525   0.769998  0.878788     0.680159       True   entropy
# 140  0.792022   0.769217  0.884848     0.680952       True      gini
# 408  0.782077   0.768736  0.860606     0.687831       True   entropy
#
#      max_depth max_features  max_leaf_nodes  min_samples_split  n_estimators  \
# 364       10.0         sqrt             NaN                 10            10
# 692        NaN         log2             NaN                 30            10
# 713        NaN         log2            20.0                 10            50
# 209       10.0         log2            20.0                 10            50
# 857       10.0         log2            20.0                 10            50
# ..         ...          ...             ...                ...           ...
# 416       10.0         log2             4.0                 30            10
# 196       10.0         log2             4.0                 10            10
# 300        5.0         sqrt             4.0                  2            10
# 140        5.0         log2            20.0                 30            10
# 408       10.0         log2             4.0                  2            10
#
#      n_jobs
# 364      -1
# 692      -1
# 713      -1
# 209      -1
# 857      -1
# ..      ...
# 416      -1
# 196      -1
# 300      -1
# 140      -1
# 408      -1
#
# [864 rows x 12 columns]

# %% [markdown]
# ### Any Patterns?
#
# `n_estimators = 10` appears in several best performers (but nearly all the worst performers...). In part this is due to the small size/complexity of the dataset. `n_estimators=200` is not common in either of the best/worst, indicating that we don't appear to gain that much from going super big (again, in part due to the small/simple dataset)
#
# Interesting that `max_leaf_nodes = 4` is common in top performing accuracy and recall. This isn't too surprisng, as ensembling often works well when we combine many "weak learners."
#
# The tradeoff between specificity and recall is really pronounced, the best and worst performers are almost inverse of each other for those metrics!
#
#
# ### Note, part 2 bonuses:
#
# The code changes are identical for part 2 and part 1, so refer to part 1 for the answers.
#
# ## Part 3: Comparing Results
#
# Write a few paragraphs summarizing the differences you've found with this dataset and these two types of model. While writing, consider the following:
#
# * Is one of these two model types better "on average"?
#     * **the best RFs are better than the best DTs**
# * Consider the best and worse performing models of each type:
#     * Are the worst performing models similarly bad, or is one much better?
#       * **No, the worst performing DTs are much worse than the worst RFs**
#     * What about the best performing, are they similarly good or is one much better?
#       * **The best RFs are slightly better than the best DTs**
# * Compare the training times for each type.
#     * Was one much faster than the other?
#         * **RF is much more expensive to train**
#     * Which hyperparameters could a major impact on time to train?
#         * **n_estimators, n_jobs, n_features are all big ones for training times**
#     * Imagine your dataset became much larger, could the time-to-train become a serious problem?
#         * **absolutely**
